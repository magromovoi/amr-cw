# %% [markdown]
# # Plotting concept similarities for the 10 Newsgroups dataset

# %% [markdown]
# ## Concept similarities for a GNN that uses an ordinary Batch Normalization layer, compared to the same GNN that uses a CW module that performed whitening, for all types of graph concepts

# %%
# %run 'main.py' --dataset ten_newsgroups --operation evaluation --mode concept_dot_product
# Out:
# GNN(
#   (lin_1): Linear(in_features=300, out_features=10, bias=True)
#   (norm1): BatchNorm(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv1): GCNConv(300, 300)
#   (conv2): GCNConv(300, 300)
# )
# 0 entertainment
# 1 graphics
# 2 historical
# 3 politics
# 4 sport
# GNN(
#   (lin_1): Linear(in_features=300, out_features=10, bias=True)
#   (norm1): IterNormRotation(300, num_channels=300, T=5, eps=1e-05, momentum=0.1, affine=False)
#   (conv1): GCNConv(300, 300)
#   (conv2): GCNConv(300, 300)
# )
# 0 entertainment
# 1 graphics
# 2 historical
# 3 politics
# 4 sport
# GNN(
#   (lin_1): Linear(in_features=300, out_features=10, bias=True)
#   (norm1): BatchNorm(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv1): GCNConv(300, 300)
#   (conv2): GCNConv(300, 300)
# )
# 0 entertainment
# 1 graphics
# 2 historical
# 3 politics
# 4 sport
# GNN(
#   (lin_1): Linear(in_features=300, out_features=10, bias=True)
#   (norm1): IterNormRotation(300, num_channels=300, T=5, eps=1e-05, momentum=0.1, affine=False)
#   (conv1): GCNConv(300, 300)
#   (conv2): GCNConv(300, 300)
# )
# 0 entertainment
# 1 graphics
# 2 historical
# 3 politics
# 4 sport
# GNN(
#   (lin_1): Linear(in_features=300, out_features=10, bias=True)
#   (norm1): BatchNorm(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv1): GCNConv(300, 300)
#   (conv2): GCNConv(300, 300)
# )
# 0 entertainment
# 1 graphics
# 2 historical
# 3 politics
# 4 sport
# GNN(
#   (lin_1): Linear(in_features=300, out_features=10, bias=True)
#   (norm1): IterNormRotation(300, num_channels=300, T=5, eps=1e-05, momentum=0.1, affine=False)
#   (conv1): GCNConv(300, 300)
#   (conv2): GCNConv(300, 300)
# )
# 0 entertainment
# 1 graphics
# 2 historical
# 3 politics
# 4 sport
# GNN(
#   (lin_1): Linear(in_features=300, out_features=10, bias=True)
#   (norm1): BatchNorm(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv1): GCNConv(300, 300)
#   (conv2): GCNConv(300, 300)
# )
# 0 entertainment
# 1 graphics
# 2 historical
# 3 politics
# 4 sport
# GNN(
#   (lin_1): Linear(in_features=300, out_features=10, bias=True)
#   (norm1): IterNormRotation(300, num_channels=300, T=5, eps=1e-05, momentum=0.1, affine=False)
#   (conv1): GCNConv(300, 300)
#   (conv2): GCNConv(300, 300)
# )
# 0 entertainment
# 1 graphics
# 2 historical
# 3 politics
# 4 sport
