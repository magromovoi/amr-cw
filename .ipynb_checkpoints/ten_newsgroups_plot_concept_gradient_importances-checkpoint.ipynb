# %% [markdown]
# # Plotting concept gradient importances for the 10 Newsgroups dataset

# %% [markdown]
# ## Concept gradient importances for the 'entertainment' document class

# %%
# %run 'main.py' --dataset ten_newsgroups --operation evaluation --mode concept_gradient_importance
# Out:
# GNN(
#   (lin_1): Linear(in_features=300, out_features=10, bias=True)
#   (norm1): IterNormRotation(300, num_channels=300, T=5, eps=1e-05, momentum=0.1, affine=False)
#   (conv1): GCNConv(300, 300)
#   (conv2): GCNConv(300, 300)
# )
# /home/eric/Eric/PhD/ResearchCode/stable-AMR-graphs-concept-whitening-testbed/iterative_normalization.py:38: UserWarning: This overload of baddbmm is deprecated:
# 	baddbmm(Number beta, Tensor input, Number alpha, Tensor batch1, Tensor batch2, *, Tensor out = None)
# Consider using one of the following signatures instead:
# 	baddbmm(Tensor input, Tensor batch1, Tensor batch2, *, Number beta = 1, Number alpha = 1, Tensor out = None) (Triggered internally at /pytorch/torch/csrc/utils/python_arg_parser.cpp:1661.)
#   Sigma = torch.baddbmm(eps, P[0], 1. / m, xc, xc.transpose(1, 2))
# ...

# %% [markdown]
# ## Concept gradient importances for the 'graphics' document class

# %%
# %run 'main.py' --dataset ten_newsgroups --operation evaluation --mode concept_gradient_importance
# Out:
# GNN(
#   (lin_1): Linear(in_features=300, out_features=10, bias=True)
#   (norm1): IterNormRotation(300, num_channels=300, T=5, eps=1e-05, momentum=0.1, affine=False)
#   (conv1): GCNConv(300, 300)
#   (conv2): GCNConv(300, 300)
# )
# /home/eric/Eric/PhD/ResearchCode/stable-AMR-graphs-concept-whitening-testbed/iterative_normalization.py:38: UserWarning: This overload of baddbmm is deprecated:
# 	baddbmm(Number beta, Tensor input, Number alpha, Tensor batch1, Tensor batch2, *, Tensor out = None)
# Consider using one of the following signatures instead:
# 	baddbmm(Tensor input, Tensor batch1, Tensor batch2, *, Number beta = 1, Number alpha = 1, Tensor out = None) (Triggered internally at /pytorch/torch/csrc/utils/python_arg_parser.cpp:1661.)
#   Sigma = torch.baddbmm(eps, P[0], 1. / m, xc, xc.transpose(1, 2))
# ...

# %% [markdown]
# ## Concept gradient importances for the 'historical' document class

# %%
# %run 'main.py' --dataset ten_newsgroups --operation evaluation --mode concept_gradient_importance
# Out:
# GNN(
#   (lin_1): Linear(in_features=300, out_features=10, bias=True)
#   (norm1): IterNormRotation(300, num_channels=300, T=5, eps=1e-05, momentum=0.1, affine=False)
#   (conv1): GCNConv(300, 300)
#   (conv2): GCNConv(300, 300)
# )
# /home/eric/Eric/PhD/ResearchCode/stable-AMR-graphs-concept-whitening-testbed/iterative_normalization.py:38: UserWarning: This overload of baddbmm is deprecated:
# 	baddbmm(Number beta, Tensor input, Number alpha, Tensor batch1, Tensor batch2, *, Tensor out = None)
# Consider using one of the following signatures instead:
# 	baddbmm(Tensor input, Tensor batch1, Tensor batch2, *, Number beta = 1, Number alpha = 1, Tensor out = None) (Triggered internally at /pytorch/torch/csrc/utils/python_arg_parser.cpp:1661.)
#   Sigma = torch.baddbmm(eps, P[0], 1. / m, xc, xc.transpose(1, 2))
# ...

# %% [markdown]
# ## Concept gradient importances for the 'politics' document class

# %%
# %run 'main.py' --dataset ten_newsgroups --operation evaluation --mode concept_gradient_importance
# Out:
# GNN(
#   (lin_1): Linear(in_features=300, out_features=10, bias=True)
#   (norm1): IterNormRotation(300, num_channels=300, T=5, eps=1e-05, momentum=0.1, affine=False)
#   (conv1): GCNConv(300, 300)
#   (conv2): GCNConv(300, 300)
# )
# /home/eric/Eric/PhD/ResearchCode/stable-AMR-graphs-concept-whitening-testbed/iterative_normalization.py:38: UserWarning: This overload of baddbmm is deprecated:
# 	baddbmm(Number beta, Tensor input, Number alpha, Tensor batch1, Tensor batch2, *, Tensor out = None)
# Consider using one of the following signatures instead:
# 	baddbmm(Tensor input, Tensor batch1, Tensor batch2, *, Number beta = 1, Number alpha = 1, Tensor out = None) (Triggered internally at /pytorch/torch/csrc/utils/python_arg_parser.cpp:1661.)
#   Sigma = torch.baddbmm(eps, P[0], 1. / m, xc, xc.transpose(1, 2))
# ...

# %% [markdown]
# ## Concept gradient importances for the 'sport' document class

# %%
# %run 'main.py' --dataset ten_newsgroups --operation evaluation --mode concept_gradient_importance
# Out:
# GNN(
#   (lin_1): Linear(in_features=300, out_features=10, bias=True)
#   (norm1): IterNormRotation(300, num_channels=300, T=5, eps=1e-05, momentum=0.1, affine=False)
#   (conv1): GCNConv(300, 300)
#   (conv2): GCNConv(300, 300)
# )
# /home/eric/Eric/PhD/ResearchCode/stable-AMR-graphs-concept-whitening-testbed/iterative_normalization.py:38: UserWarning: This overload of baddbmm is deprecated:
# 	baddbmm(Number beta, Tensor input, Number alpha, Tensor batch1, Tensor batch2, *, Tensor out = None)
# Consider using one of the following signatures instead:
# 	baddbmm(Tensor input, Tensor batch1, Tensor batch2, *, Number beta = 1, Number alpha = 1, Tensor out = None) (Triggered internally at /pytorch/torch/csrc/utils/python_arg_parser.cpp:1661.)
#   Sigma = torch.baddbmm(eps, P[0], 1. / m, xc, xc.transpose(1, 2))
# ...
